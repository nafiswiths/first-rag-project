# %% [markdown]
# data injection to vector db pipeline

# %%
import os 
from pathlib import Path
from langchain_community.document_loaders.pdf import PyPDFLoader, PyMuPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
### Read all the pdf's inside the directory

def process_all_pdfs(pdf_directory):
    """Process all PDF files in a directory"""
    all_documents = []
    pdf_dir = Path(pdf_directory)
    
    # Find all PDF files recursively
    pdf_files = list(pdf_dir.glob("**/*.pdf"))
    
    print(f"Found {len(pdf_files)} PDF files to process")
    
    for pdf_file in pdf_files:
        print(f"\nProcessing: {pdf_file.name}")
        try:
            loader = PyPDFLoader(str(pdf_file))
            documents = loader.load()
            
            # Add source information to metadata
            for doc in documents:
                doc.metadata['source_file'] = pdf_file.name
                doc.metadata['file_type'] = 'pdf'
            
            all_documents.extend(documents)
            print(f"  ✓ Loaded {len(documents)} pages")
            
        except Exception as e:
            print(f"  ✗ Error: {e}")
    
    print(f"\nTotal documents loaded: {len(all_documents)}")
    return all_documents


# Process all PDFs in the data directory
all_pdf_documents = process_all_pdfs("../data")
# Out:
# Found 2 PDF files to process
#
# Processing: Proactive_VLSI_Congestion_Prediction_Using_a_Hybrid_Residual_U-Net_with_Squeeze-and-Excitation_Blocks.pdf
#   ✓ Loaded 6 pages
#
# Processing: signal_shifting_scaling.pdf
#   ✓ Loaded 1 pages
#
# Total documents loaded: 7

# %%
all_pdf_documents
# Out:
# [Document(metadata={'producer': 'Neevia Document Converter Pro v7.3.0.184 (http://neevia.com); modified using iTextSharp 5.4.1 ©2000-2012 1T3XT BVBA (AGPL-version); modified using iText® Core 7.2.4 (AGPL version) ©2000-2022 iText Group NV', 'creator': 'Certified by IEEE PDFExpress at December 7, 2025 05:08:11', 'creationdate': '2025-12-04T18:39:00+00:00', 'meeting starting date': '19 Dec. 2025', 'moddate': '2026-04-28T00:23:49-04:00', 'ieee article id': '11491835', 'ieee issue id': '11490092', 'subject': '2025 28th International Conference on Computer and Information Technology (ICCIT);2025; ; ;10.1109/ICCIT68739.2025.11491835', 'ieee publication id': '11489965', 'title': 'Proactive VLSI Congestion Prediction Using a Hybrid Residual U-Net with Squeeze-and-Excitation Blocks', 'meeting ending date': '21 Dec. 2025', 'source': '..\\data\\pdf_files\\Proactive_VLSI_Congestion_Prediction_Using_a_Hybrid_Residual_U-Net_with_Squeeze-and-Excitation_Blocks.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1', 'source_file': 'Proactive_VLSI_Congestion_Prediction_Using_a_Hybrid_Residual_U-Net_with_Squeeze-and-Excitation_Blocks.pdf', 'file_type': 'pdf'}, page_content='2025 28th International Conference on Computer and Information Technology (ICCIT) \n19-21 December 2025, Cox’s Bazar, Bangladesh \n \n979-8-3315-7867-1/25/$31.00 ©2025 IEEE \nProactive VLSI Congestion Prediction Using a Hybrid \nResidual U-Net with Squeeze-and-Excitation Blocks \nHasibul Rahman1, Zakia Sultana2, Fabbiha Ishrar3 and Arif Istiaque4 \n1,2,3,4Department of Electronics and Telecommunication Engineering  \nChittagong University of Engineering and Technology, Chattogram 4349, Bangladesh \nEmail- hasibulrhaman123@gmail.com, zakiapranti@gmail.com, fabbihaishrar10@gmail.com, arif.ete@cuet.ac.bd \n \n \n Abstract - Routing congestion is a critical challenge in modern \nVery Large-Scale Integration (VLSI) design, as it directly impacts \ntiming closure, power efficiency, and manufacturabi lity. In the \nplacement and routing (P&R) stage of VLSI design, a ccurate \ncongestion prediction is essential to ensure routab ility, timing \nclosure, and efficient resource utilization. Tradit ional Electronic \nDesign Automation (EDA) tools rely on computationally expensive \nplacement and routing iterations to identify conges tion hotspots, \nwhich prolongs design closure cycles and increases resource \nconsumption. To address this problem, we propose a deep \nlearning-based framework for early congestion predi ction using \nfeatures derived from the CircuitNet-N14 benchmark dataset. \nOur approach integrates RUDY, RUDY_pin, and macro-r egion \nfeatures with ground truth congestion maps to const ruct a rich \nfeature representation of circuit layouts. A Residu al U-Net \nenhanced with Squeeze-and-Excitation (SE) blocks is employed to \nlearn mappings between placement features and conge stion \nheatmaps. Experimental results on multiple benchmar k designs \ndemonstrate that our model achieves competitive accuracy, with a \nStructural Similarity Index (SSIM) of 0.9724 and a normalized \nRMSE (nRMSE) of 0.0123, while significantly reducing prediction \ntime compared to conventional EDA flows. These results show that \nour framework can serve as a fast, accurate proxy for costly P&R \niterations, helping the industry accelerate design closure and \nreduce computational overhead.  \n Index Terms - Electronic Design Automation (EDA), \nPlacement and Routing (P&R), Congestion Prediction,  Residual U-\nNet, Squeeze-Excitation (SE) Blocks, Structural Sim ilarity Index \n(SSIM), Normalized Root Mean Square Error (NRMSE). \n \nI.  INTRODUCTION \nThe placement and routing (P&R) stage is one of the  most \ncritical steps in chip design. After logic synthesi s, designers \nneed to place the netlist onto the silicon floorpla n and connect \nthe components through global and detailed routing.  These \nsteps play a major role in determining wirelength, timing, \ncongestion, power distribution, and  ...
#  Document(metadata={'producer': 'Neevia Document Converter Pro v7.3.0.184 (http://neevia.com); modified using iTextSharp 5.4.1 ©2000-2012 1T3XT BVBA (AGPL-version); modified using iText® Core 7.2.4 (AGPL version) ©2000-2022 iText Group NV', 'creator': 'Certified by IEEE PDFExpress at December 7, 2025 05:08:11', 'creationdate': '2025-12-04T18:39:00+00:00', 'meeting starting date': '19 Dec. 2025', 'moddate': '2026-04-28T00:23:49-04:00', 'ieee article id': '11491835', 'ieee issue id': '11490092', 'subject': '2025 28th International Conference on Computer and Information Technology (ICCIT);2025; ; ;10.1109/ICCIT68739.2025.11491835', 'ieee publication id': '11489965', 'title': 'Proactive VLSI Congestion Prediction Using a Hybrid Residual U-Net with Squeeze-and-Excitation Blocks', 'meeting ending date': '21 Dec. 2025', 'source': '..\\data\\pdf_files\\Proactive_VLSI_Congestion_Prediction_Using_a_Hybrid_Residual_U-Net_with_Squeeze-and-Excitation_Blocks.pdf', 'total_pages': 6, 'page': 1, 'page_label': '2', 'source_file': 'Proactive_VLSI_Congestion_Prediction_Using_a_Hybrid_Residual_U-Net_with_Squeeze-and-Excitation_Blocks.pdf', 'file_type': 'pdf'}, page_content='nodes, highlighting the growing difficulty of conge stion \nmanagement in advanced technologies. With the rise of ML, \ncongestion prediction shifted from heuristic-driven  to data-\ndriven approaches. Xie et al. [8] proposed RouteNet , a CNN-\nbased framework that effectively captured spatial dependencies \nin placement layouts for routability prediction. Li u et al. [6] \nextended this by integrating deep learning into glo bal \nplacement, achieving explicit routability optimizat ion. More \nrecently, Choi et al. [7] applied ML ordering strategies in global \nrouting, demonstrating improvements in congestion \nmanagement efficiency. Datasets have been instrumen tal in \nadvancing this research direction. Chai et al. [4] introduced \nCircuitNet, an open-source dataset with domain-spec ific \nevaluation metrics tailored to routability and timi ng, while \nJiang et al. [5] accelerated routability studies us ing \nheterogeneous platforms. Cho et al. [9] reviewed br oader \napplications of ML across EDA workflows, emphasizin g its \ntransformative potential in routability analysis an d beyond. \nDespite these advances, challenges remain. Lin et a l. [3] \ndemonstrated that hotspot prediction at sub-14nm no des \nremains difficult due to increased design complexit y, while \nAlawieh et al. [6] showed that large-scale FPGA con gestion \nprediction still demands significant computational overhead. \nMoreover, existing ML-based predictors often focus on either \nnumerical accuracy or perceptual similarity of cong estion \nmaps, rarely achieving both simultaneously [4]. Res earchers \nfurther explored ML-based congestion prediction in advanced \ntechnology nodes, highlighting techniques that improve hotspot \nlocalization and reduce computational overhead by N RMSE \nvalue of 0.04 and SSIM value of 0.79 [7]. \n \n B. Research gap \nAlthough machine learning has advanced congestion prediction \nin VLSI design, current approaches still face signi ficant \nlimitations. For instance, Liu et al. [6] and Xie et al. [8] applied \nCNN-based models to predict congestion, achieving h igh \nnumerical accuracy but often compromising the perce ptual \nquality of congestion maps, which limits interpretability of fine-\ngrained hotspots. Lin et al. [4] and Chan et al. [2 ] highlighted \nthat precise hotspot localization remains challengi ng, \nparticularly at sub-14nm nodes, due to increased routing density \nand layout complexity. Furthermore, Chai et al. [4] and Jiang et \nal. [5] emphasized the importance of including placement aware \ncontextual features—such as macro-block distribution s, pin \ndensities, and regional layout characteristics—but noted that \nmany current models underutilize these features, reducing early \nprediction effectiveness. These limitations collectively indicate \nthe ne ...
#  Document(metadata={'producer': 'Neevia Document Converter Pro v7.3.0.184 (http://neevia.com); modified using iTextSharp 5.4.1 ©2000-2012 1T3XT BVBA (AGPL-version); modified using iText® Core 7.2.4 (AGPL version) ©2000-2022 iText Group NV', 'creator': 'Certified by IEEE PDFExpress at December 7, 2025 05:08:11', 'creationdate': '2025-12-04T18:39:00+00:00', 'meeting starting date': '19 Dec. 2025', 'moddate': '2026-04-28T00:23:49-04:00', 'ieee article id': '11491835', 'ieee issue id': '11490092', 'subject': '2025 28th International Conference on Computer and Information Technology (ICCIT);2025; ; ;10.1109/ICCIT68739.2025.11491835', 'ieee publication id': '11489965', 'title': 'Proactive VLSI Congestion Prediction Using a Hybrid Residual U-Net with Squeeze-and-Excitation Blocks', 'meeting ending date': '21 Dec. 2025', 'source': '..\\data\\pdf_files\\Proactive_VLSI_Congestion_Prediction_Using_a_Hybrid_Residual_U-Net_with_Squeeze-and-Excitation_Blocks.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3', 'source_file': 'Proactive_VLSI_Congestion_Prediction_Using_a_Hybrid_Residual_U-Net_with_Squeeze-and-Excitation_Blocks.pdf', 'file_type': 'pdf'}, page_content='Fig. 3: Visualization of the dataset \n \nThe dataset also offers grid-based 2D maps for cong estion, IR \ndrop, and delay, enabling CNN- and GNN-based modell ing. \nWith over 500 designs and high-resolution data (64× 64 to \n256×256 grids), CircuitNet-N14 serves as a benchmar k for \ntasks like congestion prediction, routability analysis, and power \nintegrity evaluation in advanced VLSI. \n \nTable 1 shows the statistics like number of cells, nets, count of \nmacros, and amount of samples of the designs that a re used for \ntraining and testing the model. All the samples hav e been \nmerged into a single dataset and trained the model.    \n \nTable 1: Statistics of designs inCircuitnet-14 [14] \n \nDesign Cells Nets Macros Samples \nRISCY 46,184 47,233 3 3,456 \nRISCY-\nFPU \n65,464 66,903 3 3,456 \nVortex-\nsmall \n113,961 124,058 43 96 \nNVDLA-\nsmall \n270,072 285,465 108 89 \n \nB. Data Preparation \nThe proposed methodology formulates congestion prediction as \na supervised learning problem, where the input feature tensor is \ndefined as, \n \n\x01 \x02 \x03\x01\x04\x05\x06, \x01\x04\x08\x06, \x01\x04\t\x06\n ∈ \x0c0,1\x0f\x10\x11\x12\x11\x13                                     (1) \n \nWhere, \x01\x04\x05\x06 =macro mask , \x01\x04\x08\x06 = \x14\x15\x16\x17\t\x18\x19 . Targets are \nhorizontal/vertical overflow maps \x17\x04\x1a\x06, \x17\x04\x1b\x06 ∈  \x14\x1d\n\x10\x11\x12 . Resize \noperator  \x14\x1e\x1f  maps inputs to 256 × 256 (nearest for \x01\x04\x05\x06, area \nfor others). The dataset was split into 85% trainin g, 10% \nvalidation, and 5% testing subsets, ensuring covera ge across \nmultiple architectures such as CPUs, GPUs, and acce lerators. \nThe ground truth congestion map is obtained by summ ing \nhorizontal and vertical overflow maps followed by M inMax \nnormalization, \n\x01! \x04"\x06 \x02 #\n1$ \x14\x1e\x1f %\x01\x04\x05\x06& \' 0.5*,   + \x02 ,,\n-./0\x041\x042\x063\x05\x18\x19\n\x05453\x05\x18\x19  ,   + ∈67, 89,\n                                (2) \n \n\x17! \x02 :;<:=> ?\x14\x1e\x1f %\x17\x04\x1a\x06& @ \x14\x1e\x1f %\x17\x04\x1b\x06&A ∈ \x0c0,1\x0f\x10\x11\x12         (3) \n \nWhere \x01! \x04"\x06 \x02 Normalization function. \n \nC. Squeeze and Excitation (SE) Block \nThe SE block adaptively recalibrates channel-wise f eature \nresponses by explicitly modelling interdependencies  between \nchannels. Let the input feature map be \x01 ∈ ℝ\x10\x11\x12\x11C   the \noperations are as follows: \n \nD" \x02\nE\n\x10\x11\x12 ∑ ∑ \x01" \x04;, G\x06\x12\nHIE\n\x10\n\x18IE                                                     (4) \n \nJ \x02 K%L\x1e ∙ N\x04LE ∙ D\x06&                                                             (5) \n \n\x01O" \x02 J" ∙ \x01"                                                                              (6) \n \nWhere D"  ...
#  Document(metadata={'producer': 'Neevia Document Converter Pro v7.3.0.184 (http://neevia.com); modified using iTextSharp 5.4.1 ©2000-2012 1T3XT BVBA (AGPL-version); modified using iText® Core 7.2.4 (AGPL version) ©2000-2022 iText Group NV', 'creator': 'Certified by IEEE PDFExpress at December 7, 2025 05:08:11', 'creationdate': '2025-12-04T18:39:00+00:00', 'meeting starting date': '19 Dec. 2025', 'moddate': '2026-04-28T00:23:49-04:00', 'ieee article id': '11491835', 'ieee issue id': '11490092', 'subject': '2025 28th International Conference on Computer and Information Technology (ICCIT);2025; ; ;10.1109/ICCIT68739.2025.11491835', 'ieee publication id': '11489965', 'title': 'Proactive VLSI Congestion Prediction Using a Hybrid Residual U-Net with Squeeze-and-Excitation Blocks', 'meeting ending date': '21 Dec. 2025', 'source': '..\\data\\pdf_files\\Proactive_VLSI_Congestion_Prediction_Using_a_Hybrid_Residual_U-Net_with_Squeeze-and-Excitation_Blocks.pdf', 'total_pages': 6, 'page': 3, 'page_label': '4', 'source_file': 'Proactive_VLSI_Congestion_Prediction_Using_a_Hybrid_Residual_U-Net_with_Squeeze-and-Excitation_Blocks.pdf', 'file_type': 'pdf'}, page_content="Where ℒ \x02 +c,8cJ;dS ecJJ, ℒ\\ab\\ \x02 SPfS ecJJ, X, ], ` \x02\ngS;fℎdJ. The algorithm for this process is given below: \nAlgorithm 1: Prediction Framework using Residual U-Net and \nSE block \nInput: Placement Features \x01 \nOutput: Congestion heatmap \x17O \n1. Download dataset CircuitNet-14 \n2. Extract placement feature: \n \x01 → Vj \x02 $\x14\x1e\x1f %\x01\x04\x05\x06&, \x14\x1e\x1f %\x01\x04\x08\x06&, \x14\x1e\x1f %\x01\x04\t\x06&* \n3. Generate training set \n4. Define Model (Residual UNet + SE blocks) \n5.Define SEBlock: TU ← K ?L\x1eN%LE ∙ lmn\x04D\x06&A ⨀ D \n6.Define ResBlock :  \x14SJTU\x04D\x06 ← TU%V\x04D\x06& @ D \n7.Define Down:  Dp\x1dE ← \x14SJTUp ?qc<r\x13\x11\x13,   sI\x1e\x04Dp\x06A \n8.Define Up: D!p ← qc<r\x1e\x11\x1e %\x158J=,8eS\x04Dp\x1dE\x06&;  \n9. Skip Connection with SE: \n  Dp\nu \x02 \x14SJTUp ?concat%D!p, Dp &A \n10. Final UNetSE output: \x17O ← QR\x04\x01\x06 \n11. Define Composite Loss, ℒ \n12. Define evaluation metrics (SSIM , NRMSE) \n13. for epoch in range do \n 14. model.train() \n 15. for each batch \x04\x01, \x17\x06  ∈  train_loader  do \n16.Forward Pass: \x17O ← QR\x04\x01\x06 \n17.Compute ℒ \n18.Backward + optimizer step (AMP) \n19. Evaluate on validation set:     \nℒ\x1b4p, TT_:\x1b4p\x81\x14:TU\x1b4p \n20. end for \n 21.Update scheduler \n 22.Save Checkpoint ← ℒ\x1b4p if improved \n 23. end for \n24. Repeat until convergence. \nThe Fig. 5 illustrates the full pathway a data wiil l flow in the \nmodel. The data after preprocessing stage enters in to feature \nextraction procedure. Later on,Residual U-Net + SE block \nhandles the data for loss computation and finally p redicted \ncongestion map is obtained as output.  \n \n \nFig.  5: Workflow of the model  \n \nE. Model Hyper Parameters \n \nThe ResUNet-SE model was trained using the Adam optimizer \nand a batch size of 8 for 60 epochs. The loss function combined \nMSE (weight 1.0) for pixel-wise accuracy and SSIM (weight \n0.5) for structural consistency. Total number of Trainable \nparameters are 12187045.  \nThe optimum hyper parameter values for the proposed  model \nare shown in table 2 \n \n \nTable 2: Hyper parameters utilized to train the model. \n \nHyperparameters Optimal Value \nOptimizer Adam W \nDropout Not Used \nLearning Rate  Adaptive \nBatch Size 8 \nEpoch 60 \nMSE weight 1.0 \nSSIM weight 0.5 \nBase Channel 48 \nInput Channel 3 \nOutput Channel  1 \nSE Reduction Ratio 8 \n \nThe network had 3 input channels, 1 output channel, and a base \nchannel size of 48, with an SE reduction ratio of 8  for channel \nattention. These hyper parameters were selected to ensure stable \ntraining and accurate congestion map prediction. \n \nIV.  RESULT ANALYSIS \n  \nThe evaluation is based on multiple metrics, includ ing SSIM \n(Structural Similarity Index), NRMSE (Normalized R ...
#  Document(metadata={'producer': 'Neevia Document Converter Pro v7.3.0.184 (http://neevia.com); modified using iTextSharp 5.4.1 ©2000-2012 1T3XT BVBA (AGPL-version); modified using iText® Core 7.2.4 (AGPL version) ©2000-2022 iText Group NV', 'creator': 'Certified by IEEE PDFExpress at December 7, 2025 05:08:11', 'creationdate': '2025-12-04T18:39:00+00:00', 'meeting starting date': '19 Dec. 2025', 'moddate': '2026-04-28T00:23:49-04:00', 'ieee article id': '11491835', 'ieee issue id': '11490092', 'subject': '2025 28th International Conference on Computer and Information Technology (ICCIT);2025; ; ;10.1109/ICCIT68739.2025.11491835', 'ieee publication id': '11489965', 'title': 'Proactive VLSI Congestion Prediction Using a Hybrid Residual U-Net with Squeeze-and-Excitation Blocks', 'meeting ending date': '21 Dec. 2025', 'source': '..\\data\\pdf_files\\Proactive_VLSI_Congestion_Prediction_Using_a_Hybrid_Residual_U-Net_with_Squeeze-and-Excitation_Blocks.pdf', 'total_pages': 6, 'page': 4, 'page_label': '5', 'source_file': 'Proactive_VLSI_Congestion_Prediction_Using_a_Hybrid_Residual_U-Net_with_Squeeze-and-Excitation_Blocks.pdf', 'file_type': 'pdf'}, page_content="Fig. 7: Train SSIM curve  \n \nThe NRMSE curve in Fig. 8 steadily improves (decreases), \nindicating that the model's prediction accuracy for congestion \nis improving over the epochs. The best train NRMSE of was \n0.0123.\n \n Fig. 8: Validation NRMSE curve \n \n \n Fig. 9: Learning Rate curve \nThe adaptive learning rate (LR) in Fig. 9 follows a  cosine \nannealing schedule, starting at 0.0003 and gradually decreasing \nthroughout training. This strategy helps in stabili zing the \nlearning process as the model converges. \n \n \n \nFig. 10: Performance of Proposed Model  \n \nThe validation and test predictions in Fig. 10 show  the model's \nability to accurately predict congestion in circuit  designs. The \nabsolute error maps reveal minimal discrepancies be tween the \npredicted and actual congestion, with dark areas indicating low \nerror. Signed error maps highlight areas of over- a nd under-\nprediction, while the SSIM and NRMSE metrics show excellent \nstructural similarity and low error, confirming the  model's \neffectiveness. Table 3 shows the performance indica tors \nassociated with the models. ↑ indicates “higher is better” and ↓ \nindicates “lower is better”. \n \nTable 3: Performance indicators associated with the models \nModel SSIM  ↑ NRMSE  ↓ \nsFCN+ CNN 0.5890 0.0525 \nTiny U-Net 0.6984 0.0509 \nSegNet 0.7452 0.0467 \nSegNet + SE Block 0.7553 0.0499 \nResidual U-Net + SE \nBlock (Proposed) 0.9695 0.0123 \n  \nThe proposed model combining Residual U-Net and Squ eeze \nand Excitation (SE) block shows superior SSIM and N RMSE \nvalues compared to existing models. \n \nTable 4 shows the comparison results with respect to SSIM and \nNRMSE. \n \n \n \n \n \n \n \n \n3598\nAuthorized licensed use limited to: International Islamic University Chittagong. Downloaded on June 19,2026 at 10:07:24 UTC from IEEE Xplore.  Restrictions apply."),
#  Document(metadata={'producer': 'Neevia Document Converter Pro v7.3.0.184 (http://neevia.com); modified using iTextSharp 5.4.1 ©2000-2012 1T3XT BVBA (AGPL-version); modified using iText® Core 7.2.4 (AGPL version) ©2000-2022 iText Group NV', 'creator': 'Certified by IEEE PDFExpress at December 7, 2025 05:08:11', 'creationdate': '2025-12-04T18:39:00+00:00', 'meeting starting date': '19 Dec. 2025', 'moddate': '2026-04-28T00:23:49-04:00', 'ieee article id': '11491835', 'ieee issue id': '11490092', 'subject': '2025 28th International Conference on Computer and Information Technology (ICCIT);2025; ; ;10.1109/ICCIT68739.2025.11491835', 'ieee publication id': '11489965', 'title': 'Proactive VLSI Congestion Prediction Using a Hybrid Residual U-Net with Squeeze-and-Excitation Blocks', 'meeting ending date': '21 Dec. 2025', 'source': '..\\data\\pdf_files\\Proactive_VLSI_Congestion_Prediction_Using_a_Hybrid_Residual_U-Net_with_Squeeze-and-Excitation_Blocks.pdf', 'total_pages': 6, 'page': 5, 'page_label': '6', 'source_file': 'Proactive_VLSI_Congestion_Prediction_Using_a_Hybrid_Residual_U-Net_with_Squeeze-and-Excitation_Blocks.pdf', 'file_type': 'pdf'}, page_content='Table 4: Comparison results with respect to SSIM and NRMSE \nAuthor Model SSIM NRMSE \nS. Zheng et al. [13] Lay-Net 0.7170 0.0720 \nQ. Cai, Q. Cui, Z. \nCheng [11] \nCongestionNet \n(sFCN with \nMixConv) \n0.7375 0.0514 \nH. Yang et al.[14] RouteNet 0.7805 0.0493 \nH. Li et al.[12] \nInception-\nBoosted U-\nNet \n0.7940 0.0467 \nX. Jiang et al.[5] CircuitNet \nModel 0.8000 0.0400 \n \nPROPOSED \nResidual \nUNet + \nSqueeze-\nExcitation \n0.9567 0.0123 \n \nIn conclusion, the proposed Residual U-Net with SE blocks \noffers strong performance in predicting congestion in circuit \ndesign, achieving high SSIM scores and low NRMSE values by \noutperforming previous models particularly maintain ing \naccurate predictions.  \n \n    V.   CONCLUSION AND FUTURE WORK \nIn this work, we have developed a deep learning-bas ed \nframework for early congestion prediction in the placement and \nrouting (P&R) stage of VLSI design. By leveraging f eatures \nfrom the CircuitNet-N14 dataset and employing a Res idual \nUNet enhanced with Squeeze-and-Excitation (SE) bloc ks, we \nachieved significant reductions in prediction time compared to \ntraditional EDA tools. Our model demonstrated compe titive \nperformance, with an SSIM of 0.9724 and an nRMSE of  \n0.0123, highlighting its accuracy and visual simila rity. This \nframework offers a scalable and computationally eff icient \nalternative to costly iterative P&R processes, enab ling faster \ndesign closure and optimized resource utilization. In future, we \naim to integrate the proposed framework into existi ng \nElectronic Design Automation (EDA) toolchains, enab ling \nseamless industrial deployment and real-time conges tion \nprediction during the placement and routing stages.  This \nintegration will facilitate efficient design closur e, minimize \ncomputational overhead, and streamline the overall VLSI \ndesign process. \nREFERENCES \n[1] C. Cheng, A. Kahng, I. Kang, and L. Wang, “RePlAce:  Advancing \nsolution quality and routability validation in glob al placement,” IEEE \nTrans. on Computer-Aided Design of Integrated Circu its and Systems \n(ICCAD), 2019. \n[2] W.-T. J. Chan, P.-H. Ho, A. B. Kahng, and P. Saxena , “Routability \noptimization for industrial designs at sub14nm proc ess nodes using \nmachine learning,” in ISPD ’17: Proceedings of the 2017 ACM on \nInternational Symposium on Physical Design, pp. 15–21, 2017. \n[3] M. Alawieh, W. Li, Y. Lin, L. Singhal, M. Iyer, and  D. Pan, “High-\ndefinition routing congestion prediction for larges cale FPGAs,” in Proc. \nAsia–South Pacific Design Autom. Conf. (ASP-DAC), 2020. \n[4] Z. Chai, Y. Zhao, W. Liu, Y. Lin, R. Wang, and R. H uang, “CircuitNet: \nAn open-source dataset for machine learning in VLSI  CAD applications \nwith improved domain-specific evaluation metric and learning strat ...
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': 'anonymous', 'creationdate': '2026-07-04T16:12:41+00:00', 'author': 'anonymous', 'keywords': '', 'moddate': '2026-07-04T16:12:41+00:00', 'subject': 'unspecified', 'title': 'untitled', 'trapped': '/False', 'source': '..\\data\\pdf_files\\signal_shifting_scaling.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'source_file': 'signal_shifting_scaling.pdf', 'file_type': 'pdf'}, page_content="Signal Manipulation: Shifting and Scaling in Time\nimport numpy as np\nimport matplotlib.pyplot as plt\nsignal = np.array([-5, -3, -1, 1, 3, 5, 7, 10, 17, 26])\norigin = 4\ntime = np.arange(-origin, len(signal) - origin)\nplt.figure(figsize=(10, 10))\nplt.subplot(2, 2, 1)\nplt.stem(time, signal, 'r+')\nplt.title('Original Signal x(n)')\nplt.xlabel('Time (n)')\nplt.ylabel('Amplitude')\nadvance = 8\ntime_advance = np.arange(-origin - advance, len(signal) - origin - advance)\nplt.subplot(2, 2, 2)\nplt.stem(time_advance, signal, 'b*')\nplt.title('x(n+8)')\nplt.xlabel('Time (n)')\nplt.ylabel('Amplitude')\nscale_down = 1/16\ntime_scale_down = np.linspace(-origin * scale_down,\n                              (len(signal) - origin) * scale_down,\n                              len(signal))\nplt.subplot(2, 2, 3)\nplt.stem(time_scale_down, signal, 'g*')\nplt.title('x(16n)')\nplt.xlabel('Time (n)')\nplt.ylabel('Amplitude')\nscale_up = 10\ntime_scale_up = np.linspace(-origin * scale_up,\n                            (len(signal) - origin) * scale_up,\n                            len(signal))\nplt.subplot(2, 2, 4)\nplt.stem(time_scale_up, signal, 'm*')\nplt.title('x(n/10)')\nplt.xlabel('Time (n)')\nplt.ylabel('Amplitude')\nplt.tight_layout()\nplt.show()")]

# %%
#text splitting into chunks
from langchain_core import documents


def split_documents(documents, chunk_size=1000, chunk_overlap=200):
    """Split documents into chunks"""
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        length_function=len,
        separators=["\n\n", "\n", " ", ""]
    )
    
    split_docs = text_splitter.split_documents(documents)
    print(f"split {len(documents)} documents into {len(split_docs)} chunks")
    if split_docs:
        print(f"  ✓ First chunk : {split_docs[0].page_content}...")
        print(f"  ✓ First chunk : {split_docs[1].page_content[:100]}...")
split_documents(all_pdf_documents)
# Out:
# split 7 documents into 36 chunks
#   ✓ First chunk : 2025 28th International Conference on Computer and Information Technology (ICCIT)
# 19-21 December 20...
#   ✓ First chunk : timing closure, power efficiency, and manufacturabi lity. In the
# placement and routing (P&R) stage ...
